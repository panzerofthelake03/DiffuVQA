# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True) # Ensure Google Colab module is installed
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-2500171002.py in <cell line: 0>()
#       1 from google.colab import drive
# ----> 2 drive.mount('/content/drive', force_remount=True) # Ensure Google Colab module is installed
#
# /usr/local/lib/python3.12/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      95 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#      96   """Mount your Google Drive at the specified mountpoint path."""
# ---> 97   return _mount(
#      98       mountpoint,
#      99       force_remount=force_remount,
#
# /usr/local/lib/python3.12/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     270             'https://research.google.com/colaboratory/faq.html#drive-timeout'
#     271         )
# ...

# %%
# Clone the GitHub Repository
# !git clone https://github.com/panzerofthelake03/DiffuVQA.git

# Change Directory to Project Folder
import os

project_path = '/content/DiffuVQA'
os.chdir(project_path)
print("Current Directory:", os.getcwd())
# Out:
# Cloning into 'DiffuVQA'...
# remote: Enumerating objects: 627, done.
# remote: Counting objects: 100% (401/401), done.
# remote: Enumerating objects: 627, done.
# remote: Counting objects: 100% (401/401), done.
# remote: Compressing objects: 100% (257/257), done.
# remote: Compressing objects: 100% (257/257), done.
# remote: Total 627 (delta 159), reused 366 (delta 141), pack-reused 226 (from 1)
# Receiving objects: 100% (627/627), 105.45 MiB | 32.87 MiB/s, done.
# Resolving deltas: 100% (245/245), done.
# remote: Total 627 (delta 159), reused 366 (delta 141), pack-reused 226 (from 1)
# Receiving objects: 100% (627/627), 105.45 MiB | 32.87 MiB/s, done.
# Resolving deltas: 100% (245/245), done.
# Updating files: 100% (423/423), done.
# Updating files: 100% (423/423), done.
# Current Directory: /content/DiffuVQA
# Current Directory: /content/DiffuVQA

# %%
# Install Required Libraries
# %pip install -r requirements.txt
# Out:
# ...
# ERROR: Cannot install torch==1.13.1+cu117 and torch>=1.13.1 because these package versions have conflicting dependencies.
#
# The conflict is caused by:
#     The user requested torch>=1.13.1
#     The user requested torch==1.13.1+cu117
#
# To fix this you could try to:
# 1. loosen the range of package versions you've specified
# 2. remove package versions to allow pip to attempt to solve the dependency conflict
#
# ERROR: ResolutionImpossible: for help visit https://pip.pypa.io/en/latest/topics/dependency-resolution/#dealing-with-dependency-conflicts
# ERROR: Cannot install torch==1.13.1+cu117 and torch>=1.13.1 because these package versions have conflicting dependencies.
#
# The conflict is caused by:
#     The user requested torch>=1.13.1
#     The user requested torch==1.13.1+cu117
#
# To fix this you could try to:
# 1. loosen the range of package versions you've specified
# 2. remove package versions to allow pip to attempt to solve the dependency conflict
#
# ...

# %%
# Install PyTorch with CUDA 11.8
# %pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu118
# %pip install transformers datasets tokenizers sentencepiece huggingface-hub accelerate
# %pip install numpy pyarrow scikit-learn psutil tqdm packaging pandas openpyxl
# %pip install Pillow nltk torchmetrics bert_score pycocoevalcap sentence-transformers spacy
# %pip install blobfile wandb PyYAML setuptools typing-extensions
# %pip install torchmetrics==0.11.4
# !python --version
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu118
# ...
#   Using cached torchmetrics-1.8.2-py3-none-any.whl.metadata (22 kB)
# ...
#   Using cached bert_score-0.3.13-py3-none-any.whl.metadata (15 kB)
# ...
#   Using cached pycocoevalcap-1.2-py3-none-any.whl.metadata (3.2 kB)
# ...
#   Using cached torchmetrics-1.8.2-py3-none-any.whl.metadata (22 kB)
# ...
#   Using cached bert_score-0.3.13-py3-none-any.whl.metadata (15 kB)
# ...
#   Using cached pycocoevalcap-1.2-py3-none-any.whl.metadata (3.2 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 983.2/983.2 kB 20.5 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/61.1 kB ? eta -:--:--Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers>=3.0.0->bert_score) (0.22.1)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 983.2/983.2 kB 20.5 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.1/61.1 kB 4.9 MB/s eta 0:00:00
# ...

# %%
# Run the Main Script or Any Other File
# Replace 'main.py' with the script you want to execute
# !python train.py --lr 0.0001 --batch_size 4 --learning_steps 100 --save_interval 100 --log_interval 25 --data_dir "datasets" --image_dir "datasets/slake/imgs/imgs" --dataset "slake"
# Out:
# 2025-11-30 12:15:33.276344: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1764504933.296039    5499 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1764504933.302398    5499 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1764504933.317469    5499 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
# !ls /content/
# !ls /content/DiffuVQA/
# !ls /content/DiffuVQA/checkpoints/
# !ls /content/DiffuVQA/datasets/
# !ls /content/DiffuVQA/checkpoints/batch4_lr0.0001/
# Out:
# DiffuVQA  sample_data
#  basic_utils.py
#  checkpoints
#  compare_samples.py
#  config
#  datasets
#  diffusion_models
#  diffuvqa
#  efficient_sample.py
#  ema_0.9999_300000.pt.samples.jsonl
#  enhanced_eval_metrics.py
#  eva_DiffuVQA.py
#  eval_DiffuVQA.py
#  excel_export_module.py
# 'git reset --hard 828cedcf3eb63f5659f457b6dc739ffe76eb639d'
#  img
#  prepare_eval.py
#  __pycache__
#  README.md
#  reports
#  requirements.txt
#  run_experiments.ps1
#  samples
#  sample_vqa_GPU.py
#  scripts
#  temp_seed105_only
#  test_enhanced_metrics.py
#  texts
#  train.py
#  train_util.py
#  wandb
# batch4_lr0.0001  batch4_lr0.0005  batch6_lr0.0001  batch6_lr0.0005
# test.jsonl  train.jsonl  valid.jsonl
# random_emb.torch       special_tokens_map.json	tokenizer.json	    vocab.txt
# random_emb.torch.done  tokenizer_config.json	training_args.json
